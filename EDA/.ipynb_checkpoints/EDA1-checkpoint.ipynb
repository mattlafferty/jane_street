# %%
import kaggle
import pandas as pd
import os
import seaborn as sns

# %%
os.chdir("/Users/matthewlafferty/Dropbox/Kaggle/Jane_Street/jane-street-market-prediction")

# %%
data = pd.read_csv('train.csv')

# %%
data.sample(10)
# Out:
#          date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 187913     29   0.138753  0.003446  0.002499 -0.026999 -0.096753 -0.079522
# 178383     27   0.322137  0.001492  0.001712  0.001569  0.003690  0.004345
# 2286892   480   0.793643 -0.001696 -0.003157  0.007290  0.009294  0.002773
# 1863304   396   0.211641  0.004564  0.003911  0.002391 -0.002440 -0.002723
# 425482     66   5.410452  0.001322  0.003088 -0.002405  0.005267  0.012310
# 2315565   486   0.000000  0.006053  0.004217  0.007083  0.007493  0.003718
# 435065     68  14.268053 -0.001093  0.002020  0.004921  0.006353  0.006274
# 1981335   423   0.000000  0.000305  0.001052 -0.003724 -0.011270 -0.005962
# 654204    120   0.000000  0.000310  0.000310 -0.003848 -0.003118  0.003834
# 1284149   274   4.083542  0.002774  0.007807  0.009256  0.005116  0.009114
#
#          feature_0  feature_1  feature_2  ...  feature_121  feature_122  \
# ...

# %%
sns.lineplot(x = 'ts_id', y = 'resp', data = data)

# %%
data['weight'].describe()
# Out:
# count    2.390491e+06
# mean     3.031535e+00
# std      7.672794e+00
# min      0.000000e+00
# 25%      1.617400e-01
# 50%      7.086770e-01
# 75%      2.471791e+00
# max      1.672937e+02
# Name: weight, dtype: float64

# %%
sns.set(rc={'figure.figsize':(13,11)})

# %%
sns.scatterplot(x='feature_0', y='resp', data = data.sample(frac=0.1))

# %%
sns.scatterplot(x='feature_1', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_2', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_3', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_4', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_5', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_6', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_7', y='resp', data = data.sample(frac=0.1), alpha = 0.3)

# %%
sns.scatterplot(x='feature_8', y='resp', data = data.sample(frac=0.1), alpha = 0.3)
